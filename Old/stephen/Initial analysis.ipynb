# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
per_capita_alcohol = "Resources/per-capita-alcohol-1890.csv"
mental_health_data = "Resources/share-with-mental-and-substance-disorders.csv"
happiness_data = "Resources/happiness-cantril-ladder.csv"
wine_consumption = "Resources/wine-consumption-per-person.csv"
alcohol_expenditure = "Resources/alcohol-expenditure-as-share-of-total.csv"

per_capita_alcohol_df = pd.read_csv(per_capita_alcohol)
mental_health_data_df = pd.read_csv(mental_health_data)
happiness_data_df = pd.read_csv(happiness_data)
wine_consumption_df = pd.read_csv(wine_consumption)
alcohol_expenditure_df = pd.read_csv(alcohol_expenditure)

#merging per capita alcohol & mental health

# %%
per_capita_alcohol_df.head()
# Out:
#       Entity Code  Year  \
# 0  Australia  AUS  1890
# 1  Australia  AUS  1920
# 2  Australia  AUS  1960
# 3  Australia  AUS  1970
# 4  Australia  AUS  1980
#
#    Alcohol consumption since 1890 (Alexander & Holmes, 2017)
# 0                                                5.9
# 1                                                3.8
# 2                                                7.1
# 3                                                9.5
# 4                                                9.7

# %%
mental_health_data_df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Percent)
# 0                                          17.553463
# 1                                          17.837032
# 2                                          18.092542
# 3                                          18.294931
# 4                                          18.428908

# %%
print(len(mental_health_data_df))
print(len(per_capita_alcohol_df))
# Out:
# 6468
# 121

# %%
entity_and_mental_health_df = pd.merge(per_capita_alcohol_df, mental_health_data_df, how='outer', on=['Entity'])
alcohol_and_mental_health_df
# Out:
#          Entity Code  Year  \
# 0     Australia  AUS  1890
# 1     Australia  AUS  1920
# 2     Australia  AUS  1960
# 3     Australia  AUS  1970
# 4     Australia  AUS  1980
# ...         ...  ...   ...
# 6533   Zimbabwe  ZWE  2013
# 6534   Zimbabwe  ZWE  2014
# 6535   Zimbabwe  ZWE  2015
# 6536   Zimbabwe  ZWE  2016
# 6537   Zimbabwe  ZWE  2017
#
#       Alcohol consumption since 1890 (Alexander & Holmes, 2017)  \
# 0                                                   5.9
# 1                                                   3.8
# 2                                                   7.1
# 3                                                   9.5
# 4                                                   9.7
# ...                                                 ...
# 6533                                                NaN
# 6534                                                NaN
# 6535                                                NaN
# ...

# %%
entity_and_mental_health_df = pd.merge(per_capita_alcohol_df, mental_health_data_df, how='outer', on=['Entity'])
alcohol_and_mental_health_df.sample(10)
# Out:
#                       Entity Code  Year  \
# 4473                Pakistan  PAK  2013
# 2784                 Iceland  ISL  2017
# 1549                 Croatia  HRV  2002
# 5540               Sri Lanka  LKA  2016
# 2381               Greenland  GRL  2006
# 1890                 Ecuador  ECU  2010
# 5954  Tropical Latin America  NaN  2016
# 1836          Eastern Europe  NaN  2012
# 1872                 Ecuador  ECU  1992
# 3586                Malaysia  MYS  2013
#
#       Alcohol consumption since 1890 (Alexander & Holmes, 2017)  \
# 4473                                                NaN
# 2784                                                NaN
# 1549                                                NaN
# 5540                                                NaN
# 2381                                                NaN
# 1890                                                NaN
# 5954                                                NaN
# 1836                                                NaN
# ...

# %%
dataframe_no_repeats = alcohol_and_mental_health_df.dropna()
print(len(dataframe_no_repeats))
dataframe_no_repeats
# Out:
# 51
#              Entity Code  Year  \
# 5         Australia  AUS  1990
# 6         Australia  AUS  2000
# 7         Australia  AUS  2014
# 11          Austria  AUT  1990
# 12          Austria  AUT  2000
# 13          Austria  AUT  2014
# 19          Belgium  BEL  1990
# 20          Belgium  BEL  2000
# 21          Belgium  BEL  2014
# 25           Canada  CAN  1990
# 26           Canada  CAN  2000
# 27           Canada  CAN  2014
# 32          Denmark  DNK  1990
# 33          Denmark  DNK  2000
# 34          Denmark  DNK  2014
# 38          Finland  FIN  1990
# 39          Finland  FIN  2000
# 40          Finland  FIN  2014
# 46           France  FRA  1990
# 47           France  FRA  2000
# 48           France  FRA  2014
# 54          Germany  DEU  1990
# 55          Germany  DEU  2000
# 56          Germany  DEU  2014
# 62            Italy  ITA  1990
# 63            Italy  ITA  2000
# 64            Italy  ITA  2014
# 68            Japan  JPN  1990
# 69            Japan  JPN  2000
# ...

# %%
dataframe = dataframe_no_repeats.rename(columns={"Alcohol consumption since 1890 (Alexander & Holmes, 2017)":"Alcohol Consumption", "Prevalence - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Percent)":"Prevalence of Disorders"})
dataframe.head()
# Out:
#        Entity Code  Year  Alcohol Consumption  Prevalence of Disorders
# 5   Australia  AUS  1990                  8.1                18.077892
# 6   Australia  AUS  2000                  8.1                18.270331
# 7   Australia  AUS  2014                  7.3                18.509090
# 11    Austria  AUT  1990                 11.0                14.648111
# 12    Austria  AUT  2000                 10.3                14.569349

# %%
dataframe.plot.scatter(x='Alcohol Consumption', y='Prevalence of Disorders')
plt.title("Alcohol Consumption vs Prevalence of Disorders")
plt.show()
#Not a particularly strong correlation either way
