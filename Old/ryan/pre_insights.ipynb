# %%
import pandas as pd
import numpy as np
from scipy import stats as sts
from matplotlib import pyplot as plt

# %%
happy_data = pd.read_csv('Resources/happiness-cantril-ladder.csv')
anxiety_data = pd.read_csv('Resources/number-with-anxiety-disorders.csv')
drinks_data = pd.read_csv('Resources/drinks_solution.csv')
wine_data = pd.read_csv('Resources/Wine Production By Country.csv', delimiter=';')

# %%
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2008
# 1  Afghanistan  AFG  2009
# 2  Afghanistan  AFG  2010
# 3  Afghanistan  AFG  2011
# 4  Afghanistan  AFG  2012
#
#    Life satisfaction in Cantril Ladder (World Happiness Report 2019)
# 0                                           3.723590
# 1                                           4.401778
# 2                                           4.758381
# 3                                           3.831719
# 4                                           3.782938

# %%
drinks_data = drinks_data.rename(columns={'country':'Entity'})
combined_df = pd.merge(happy_data, anxiety_data, on=['Entity','Code'], how='outer')
combined_df = combined_df.dropna()
combined_df = combined_df.rename(columns={'Prevalence - Anxiety disorders - Sex: Male - Age: All Ages (Number)': 'num_males_with_anxiety'})
combined_df = combined_df.rename(columns={'Prevalence - Anxiety disorders - Sex: Female - Age: All Ages (Number)': 'num_females_with_anxiety'})
combined_df = combined_df.rename(columns={'Life satisfaction in Cantril Ladder (World Happiness Report 2019)': 'happy_score'})

combined_df.head()
# Out:
#         Entity Code  Year_x  happy_score  Year_y  num_males_with_anxiety  \
# 0  Afghanistan  AFG  2008.0      3.72359  1990.0           164475.899445
# 1  Afghanistan  AFG  2008.0      3.72359  1991.0           170087.377635
# 2  Afghanistan  AFG  2008.0      3.72359  1992.0           199894.632147
# 3  Afghanistan  AFG  2008.0      3.72359  1993.0           231159.684414
# 4  Afghanistan  AFG  2008.0      3.72359  1994.0           238886.225430
#
#    num_females_with_anxiety
# 0             252379.267264
# 1             262036.445129
# 2             310572.487808
# 3             361936.608315
# 4             376216.938911

# %%
combined_df = combined_df[combined_df['Year_y'] > 2007]
male_anxiety_prev = combined_df['num_males_with_anxiety']
female_anxiety_prev = combined_df['num_females_with_anxiety']

combined_df.head()
country_group = combined_df.groupby(['Entity'])
df = country_group.mean()

# df.head()

# %%
f, ax = plt.subplots(figsize=(25,5))
plt.bar(df.index, df['num_males_with_anxiety'], label='male')
plt.bar(df.index, df['num_females_with_anxiety'], label='female')
plt.xticks(rotation=90)
ax.legend(fontsize=14)
plt.show()

# %%
happy_data.head()
country_year_happy = happy_data.groupby(['Entity', 'Year'])
grouped_happy_data = country_year_happy.mean()
grouped_happy_data = happy_data.rename(columns={'Life satisfaction in Cantril Ladder (World Happiness Report 2019)': 'happy_rating'})
grouped_happy_data
# Out:
#            Entity Code  Year  happy_rating
# 0     Afghanistan  AFG  2008      3.723590
# 1     Afghanistan  AFG  2009      4.401778
# 2     Afghanistan  AFG  2010      4.758381
# 3     Afghanistan  AFG  2011      3.831719
# 4     Afghanistan  AFG  2012      3.782938
# ...           ...  ...   ...           ...
# 1699     Zimbabwe  ZWE  2014      4.184451
# 1700     Zimbabwe  ZWE  2015      3.703191
# 1701     Zimbabwe  ZWE  2016      3.735400
# 1702     Zimbabwe  ZWE  2017      3.638300
# 1703     Zimbabwe  ZWE  2018      3.616480
#
# [1704 rows x 4 columns]

# %%
grouped_happy_data.unstack().plot(kind='bar', figsize=(25,5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-e56fff2caea0> in <module>
# ----> 1 grouped_happy_data.unstack().plot(kind='bar', figsize=(25,5))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
country_happy = happy_data.groupby('Entity')
df = country_happy.mean()
df['country'] = df.index
df.index = np.arange(len(df))
df
# Out:
#             Year  \
# 0    2013.000000
# 1    2012.909091
# 2    2014.000000
# 3    2012.500000
# 4    2012.000000
# ..           ...
# 159  2011.846154
# 160  2012.000000
# 161  2012.909091
# 162  2012.166667
# 163  2012.000000
#
#      Life satisfaction in Cantril Ladder (World Happiness Report 2019)  \
# 0                                             3.705495
# 1                                             4.990211
# 2                                             5.481872
# 3                                             4.420299
# 4                                             6.358951
# ..                                                 ...
# 159                                           6.203183
# 160                                           5.293443
# 161                                           3.886234
# 162                                           4.631722
# 163                                           4.029770
#
#          country
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3         Angola
# 4      Argentina
# ..           ...
# 159    Venezuela
# 160      Vietnam
# 161        Yemen
# 162       Zambia
# 163     Zimbabwe
#
# [164 rows x 3 columns]

# %%
drinks_data_df = drinks_data.rename(columns={"Entity":"country"})
drinks_data_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.3
# 4                           5.7

# %%
drinks_data
happy_servings_df = pd.merge(df, drinks_data_df, on='country', how='inner')
happy_servings_df
#renaming columns to fix code
happy_servings = happy_servings_df.rename(columns={"Life satisfaction in Cantril Ladder (World Happiness Report 2019)":"happy_rating"})
happy_servings
# Out:
#             Year  happy_rating      country  beer_servings  spirit_servings  \
# 0    2013.000000      3.705495  Afghanistan              0                0
# 1    2012.909091      4.990211      Albania             89              132
# 2    2014.000000      5.481872      Algeria             25                0
# 3    2012.500000      4.420299       Angola            217               57
# 4    2012.000000      6.358951    Argentina            193               25
# ..           ...           ...          ...            ...              ...
# 145  2011.846154      6.203183    Venezuela            333              100
# 146  2012.000000      5.293443      Vietnam            111                2
# 147  2012.909091      3.886234        Yemen              6                0
# 148  2012.166667      4.631722       Zambia             32               19
# 149  2012.000000      4.029770     Zimbabwe             64               18
#
#      wine_servings  total_litres_of_pure_alcohol
# 0                0                           0.0
# 1               54                           4.9
# 2               14                           0.7
# 3               45                           5.7
# 4              221                           7.8
# ..             ...                           ...
# 145              3                           7.7
# 146              1                           2.0
# 147              0                           0.1
# 148              4                           1.0
# 149              4                           1.5
#
# [150 rows x 7 columns]

# %%
plt.scatter(happy_servings['happy_rating'], happy_servings['beer_servings'], c='plum')
x = happy_servings['happy_rating']
y = happy_servings['beer_servings']
slope, intercept, r_value, p_value, std_err = sts.linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
reg_str = 'y='+ str(round(slope, 2)) +'x+' + str(round(intercept, 2))
plt.annotate(reg_str, (6.5,100), fontsize=15, color='red' )
plt.title('Number of Beer Servings vs Happiness Score')
plt.xlabel('Happiness score')
plt.ylabel('Num of Beer Servings')
plt.savefig('output/beer_to_happiness.png', dpi=400)
plt.show()
print(r_value)

plt.scatter(happy_servings['happy_rating'], happy_servings['wine_servings'], c='blue')
y = happy_servings['wine_servings']
slope, intercept, r_value, p_value, std_err = sts.linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
reg_str = 'y='+ str(round(slope, 2)) +'x+' + str(round(intercept, 2))
plt.annotate(reg_str, (6.5,85), fontsize=15, color='red' )
plt.title('Number of Wine Servings vs Happiness Score')
plt.xlabel('Happiness score')
plt.ylabel('Num of Wine Servings')
plt.savefig('output/wine_to_happiness.png', dpi=400)
plt.show()
print(r_value)

plt.scatter(happy_servings['happy_rating'], happy_servings['spirit_servings'])
y = happy_servings['spirit_servings']
slope, intercept, r_value, p_value, std_err = sts.linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
reg_str = 'y='+ str(round(slope, 2)) +'x+' + str(round(intercept, 2))
plt.annotate(reg_str, (6.5,85), fontsize=15, color='red' )
plt.title('Number of Spirit Servings vs Happiness Score')
plt.xlabel('Happiness score')
plt.ylabel('Num of Spirit Servings')
plt.savefig('output/spirit_to_happiness.png', dpi=400)
plt.show()
print(r_value)

plt.scatter(happy_servings['happy_rating'], happy_servings['total_litres_of_pure_alcohol'], c='green')
y = happy_servings['total_litres_of_pure_alcohol']
slope, intercept, r_value, p_value, std_err = sts.linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
reg_str = 'y='+ str(round(slope, 2)) +'x+' + str(round(intercept, 2))
plt.annotate(reg_str, (6.5,4), fontsize=15, color='red')
plt.title('Total Alcohol Servings vs Happiness Score')
plt.xlabel('Happiness score')
plt.ylabel('Num of Total Alc Servings')
plt.savefig('output/total_alc_to_happiness.png', dpi=400)
plt.show()
print(r_value)
# Out:
# 0.5209343012237079
# 0.5068346368726675
# 0.29642591221097386
# 0.5735432718342407

# %%
alc_expend_data = pd.read_csv('Resources/alcohol-expenditure-as-share-of-total.csv')
alc_expend_data = alc_expend_data.rename(columns={'Indicator:Alcohol expenditure as a per cent of total household expenditure': 'alc_purchase_percent_of_total_income'})
alc_expend_data
# Out:
#          Entity Code  Year  alc_purchase_percent_of_total_income
# 0       Albania  ALB  2007                                   2.1
# 1       Albania  ALB  2012                                   5.1
# 2       Albania  ALB  2013                                   4.8
# 3       Albania  ALB  2014                                   4.5
# 4       Armenia  ARM  1990                                   4.0
# ..          ...  ...   ...                                   ...
# 472  Uzbekistan  UZB  1992                                   3.2
# 473  Uzbekistan  UZB  1993                                   2.9
# 474  Uzbekistan  UZB  1994                                   2.5
# 475  Uzbekistan  UZB  1995                                   1.9
# 476    Zimbabwe  ZWE  1990                                   7.0
#
# [477 rows x 4 columns]

# %%
countries = alc_expend_data['Code']

d = {ni: indi for indi, ni in enumerate(set(countries))}
numbers = [d[ni] for ni in countries]

years = alc_expend_data['Year']
spending = alc_expend_data['alc_purchase_percent_of_total_income']

# %%
place = alc_expend_data['Entity']

plot_color_legend = pd.DataFrame(set(zip(numbers, place)))

plot_color_legend
# Out:
#      0                1
# 0   42      Netherlands
# 1   48           Sweden
# 2   43            Italy
# 3   31          Georgia
# 4   47           Canada
# 5   16       Azerbaijan
# 6   23          Albania
# 7   35          Denmark
# 8   51           Russia
# 9    6       Kyrgyzstan
# 10  40         Slovenia
# 11  46     South Africa
# 12   8     Turkmenistan
# 13  17           Latvia
# 14  32            Spain
# 15   3     Cook Islands
# 16  54          Belarus
# 17  12        Singapore
# 18  41          Croatia
# 19  15  North Macedonia
# 20  28            Samoa
# 21  38        Lithuania
# 22  11      New Zealand
# 23  14          Lebanon
# 24  39         Ethiopia
# 25  20            Palau
# 26  33   United Kingdom
# 27   4        Australia
# 28  19            Japan
# 29  34    United States
# 30  53          Hungary
# 31  27          Czechia
# 32  22          Romania
# 33  50          Estonia
# 34   2         Thailand
# 35  26           Norway
# 36   5          Iceland
# 37  13           Mexico
# 38  44           Cyprus
# 39  52          Ukraine
# 40  10          Finland
# 41  29      Philippines
# 42  37       Uzbekistan
# 43  45          Moldova
# 44  24           Bhutan
# 45   9           France
# 46   1       Tajikistan
# 47  21       Kazakhstan
# 48  30          Armenia
# 49   0          Austria
# 50  49         Zimbabwe
# 51  18           Greece
# 52   7          Ireland
# 53  25       Seychelles
# 54  36           Poland

# %%
# no x label?
alc_expend_data.plot.scatter('Year', 'alc_purchase_percent_of_total_income', c=numbers, colormap='jet');
plt.grid(True)

# %%
# mega_df = pd.read_csv('../Alison/mega_df.csv')
mega_df_with_climate = pd.read_csv('../mega_df_with_climate.csv')
# mega_df.head()

# %%
 mega_df_with_climate.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 continent country_code      country  \
# 0           0             0      Asia          AFG  Afghanistan
# 1           1             1    Europe          ALB      Albania
# 2           2          4942    Africa          DZA      Algeria
# 3           3          4943    Europe          AND      Andorra
# 4           4          4944    Africa          AGO       Angola
#
#    consumption_per_capita_(L)  \
# 0                         0.2
# 1                         7.5
# 2                         0.9
# 3                        11.3
# 4                         6.4
#
#                                              climate  \
# 0     arid to semiarid; cold winters and hot summers
# 1  mild temperate; cool, cloudy, wet winters; hot...
# 2  arid to semiarid; mild, wet winters with hot, ...
# 3  temperate; snowy, cold winters and warm, dry s...
# 4  semiarid in south and along coast to Luanda; n...
#
#                     main_export                     main_industry  \
# 0                Fruit and nuts  small-scale production of bricks
# 1  Chromium and chrome products    perfumes and cosmetic products
# 2                           Oil                         petroleum
# 3              Tobacco products                          tourism
# 4                           Oil                         petroleum
#
#                          region  happy_score  life_expectancy  gdp_per_capita  \
# 0                    South Asia       2.5669        52.590000        7.462861
# 1    Central and Eastern Europe       4.8827        68.708138        9.417931
# 2  Middle East and North Africa       5.0051        65.905174        9.537965
# 3                           NaN          NaN              NaN             NaN
# 4                           NaN          NaN              NaN             NaN
#
#   code  mental_health_and_addiction (%) Climate_Fixed
# 0  AFG                        17.553463          Arid
# 1  ALB                        10.987610     Temperate
# 2  DZA                        14.700388          Arid
# 3  AND                        14.726869     Temperate
# 4  AGO                        12.498281      Tropical

# %%
countries = mega_df_with_climate['country']

# %%
# # happy v. consumption by country

# consumption_happy = mega_df_with_climate[['consumption_per_capita_(L)', 'happy_score']]

# d = {ni: indi for indi, ni in enumerate(set(countries))}
# numbers = [d[ni] for ni in countries]

# consumption_happy.plot.scatter('consumption_per_capita_(L)', 'happy_score', c=numbers, colormap='jet');
# plt.grid(True)

# consumption_happy.head()

# %%
# plot_color_legend = pd.DataFrame(set(zip(numbers, countries)))

# plot_color_legend

# %%
# # Mental Health v. consumption by country

# consumption_mental = mega_df_with_climate[['consumption_per_capita_(L)', 'mental_health_and_addiction (%)']]
# consumption_mental.plot.scatter('consumption_per_capita_(L)', 'mental_health_and_addiction (%)', c=numbers, colormap='jet');
# plt.grid(True)

# %%
import seaborn as sns

sns.set_style(style="darkgrid")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=mega_df_with_climate,
    x="happy_score", y="consumption_per_capita_(L)",
    hue='gdp_per_capita', size='life_expectancy',
    palette=cmap, sizes=(10, 200),
)


# g.set(xscale="log", yscale="log")
plt.title('Happy Score v. Alcohol Consumption')
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True);

#reg
sns.set_style(style="darkgrid")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=mega_df_with_climate,
    x="happy_score", y="consumption_per_capita_(L)",
    hue='happy_score', size="consumption_per_capita_(L)",
    palette=cmap, sizes=(10, 200),
)


# g.set(xscale="log", yscale="log")
plt.title('Happy Score v. Alcohol Consumption')
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True);

# %%
sns.set_style(style="darkgrid")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=mega_df_with_climate,
    x="mental_health_and_addiction (%)", y="consumption_per_capita_(L)",
    hue='gdp_per_capita', size='life_expectancy',
    palette=cmap, sizes=(10, 200),
)

# g.set(xscale="log", yscale="log")
plt.title('Mental Health/Addiction v. Alcohol Consumption')
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True);

sns.set_style(style="darkgrid")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=mega_df_with_climate,
    x="mental_health_and_addiction (%)", y="consumption_per_capita_(L)",
    hue='mental_health_and_addiction (%)', size="consumption_per_capita_(L)",
    palette=cmap, sizes=(10, 200),
)
# g.set(xscale="log", yscale="log")
plt.title('Mental Health/Addiction v. Alcohol Consumption')
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True);

# %%
by_region = mega_df_with_climate.groupby('region')

# %%
alc_consumption_over_time = pd.read_csv('Resources/per-capita-alcohol-1890.csv')
alc_consumption_over_time.head()
# Out:
#       Entity Code  Year  \
# 0  Australia  AUS  1890
# 1  Australia  AUS  1920
# 2  Australia  AUS  1960
# 3  Australia  AUS  1970
# 4  Australia  AUS  1980
#
#    Alcohol consumption since 1890 (Alexander & Holmes, 2017)
# 0                                                5.9
# 1                                                3.8
# 2                                                7.1
# 3                                                9.5
# 4                                                9.7

# %%
places = alc_consumption_over_time['Entity'].unique()

plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')

for place in places:
    place_df = alc_consumption_over_time[alc_consumption_over_time['Entity'] == place]
    x = place_df['Year']
    y = place_df['Alcohol consumption since 1890 (Alexander & Holmes, 2017)']
    plt.plot(x, y, label=f'{place}')
    
plt.xlabel('Years')
plt.ylabel('Alc Consumed (L)/ yr')
plt.legend();

# %%
alc_consumption_over_time = alc_consumption_over_time.rename(columns={'Entity': 'country'})

# %%
#maybe plot the top 5 drunkest countries 
sample = mega_df_with_climate.sample(5)

ax = sns.boxplot(x="country", y="consumption_per_capita_(L)", data=sample)
# ax = sns.swarmplot(x="country", y="consumption_per_capita_(L)", data=sample, color=".25")
