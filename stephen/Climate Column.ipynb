# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
mega_df = "../mega_df.csv"

mega_df= pd.read_csv(mega_df)

# %%
mega_df.head()
# Out:
#    Unnamed: 0 continent country_code      country  consumption_per_capita_(L)  \
# 0           0      Asia          AFG  Afghanistan                         0.2
# 1           1    Europe          ALB      Albania                         7.5
# 2        4942    Africa          DZA      Algeria                         0.9
# 3        4943    Europe          AND      Andorra                        11.3
# 4        4944    Africa          AGO       Angola                         6.4
#
#                                              climate  \
# 0     arid to semiarid; cold winters and hot summers
# 1  mild temperate; cool, cloudy, wet winters; hot...
# 2  arid to semiarid; mild, wet winters with hot, ...
# 3  temperate; snowy, cold winters and warm, dry s...
# 4  semiarid in south and along coast to Luanda; n...
#
#                     main_export                     main_industry  \
# 0                Fruit and nuts  small-scale production of bricks
# ...

# %%
#added new column wiht blank values to fill
mega_df["Climate_Fixed"]= ""

# %%
#mega_df.loc[mega_df['climate'].isin(["arid","desert"]) , 'Climate_Fixed'] = 'Arid'

# %%
mega_df.loc[mega_df['climate'] == 'arid', 'Climate_Fixed'] = "Arid"

# %%
mega_df
# Out:
#      Unnamed: 0      continent country_code      country  \
# 0             0           Asia          AFG  Afghanistan
# 1             1         Europe          ALB      Albania
# 2          4942         Africa          DZA      Algeria
# 3          4943         Europe          AND      Andorra
# 4          4944         Africa          AGO       Angola
# ..          ...            ...          ...          ...
# 181        5128           Asia          UZB   Uzbekistan
# 182        5129  South America          VEN    Venezuela
# 183        5130        Oceania          WSM        Samoa
# 184        5131           Asia          YEM        Yemen
# 185        5132         Africa          ZMB       Zambia
#
#      consumption_per_capita_(L)  \
# 0                           0.2
# 1                           7.5
# 2                           0.9
# 3                          11.3
# 4                           6.4
# ..                          ...
# 181                         2.7
# ...

# %%
mega_df.to_csv("climate_mega_df.csv")
